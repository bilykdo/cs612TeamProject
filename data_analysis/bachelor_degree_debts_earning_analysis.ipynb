# %%
import numpy as np
import pandas as pd

# %%
sortedByDebtPayment10YR = pd.read_csv('bachelor_degree_analysis_sortedByDebtPayment10YR.csv')
sortedByDataAvailabilityCount = pd.read_csv('bachelor_degree_analysis_sortedByDataAvailabilityCount.csv')
bachelorDegreesPay = pd.read_csv('datasets_1189_2137_degrees-that-pay-back.csv')
bachelorDegreesPay
# Out:
#                      Undergraduate Major Starting Median Salary  \
# 0                             Accounting             $46,000.00
# 1                  Aerospace Engineering             $57,700.00
# 2                            Agriculture             $42,600.00
# 3                           Anthropology             $36,800.00
# 4                           Architecture             $41,600.00
# 5                            Art History             $35,800.00
# 6                                Biology             $38,800.00
# 7                    Business Management             $43,000.00
# 8                   Chemical Engineering             $63,200.00
# 9                              Chemistry             $42,600.00
# 10                     Civil Engineering             $53,900.00
# 11                        Communications             $38,100.00
# 12                  Computer Engineering             $61,400.00
# 13                      Computer Science             $55,900.00
# ...

# %%
# Bachelor Degree data
# The top 3 majors based on the most data provided are:
# 1431 feeds for: Business Administration, Management and Operations.	
# 1098 feeds for: Psychology, General.	
# 910 feeds for: Registered Nursing, Nursing Administration, Nursing Research and Clinical Nursing.	

# We pick only records with over 200 feeds available for research
sortedByDataAvailabilityCount[(sortedByDataAvailabilityCount['P_CIPDESC'] > 200)]

# # To select Bachelor degree we use label P_CREDLEV and integer 3 that represent Bachelor degree column
# bachelorDegrees = cleanData[(cleanData['P_CREDLEV'] == 3)]
# sortedByDebtMeanBachelorDegrees = bachelorDegrees.sort_values(by ='P_DEBTMEAN')

# # Select specific columns to output the data
# outputData = sortedByDebtMeanBachelorDegrees[['P_INSTNM', 'P_CIPDESC', 'P_DEBTMEDIAN', 'P_DEBTPAYMENT10YR', 'P_DEBTMEAN']]

# # Save data sorted by DEBTMEAN
# outputData.to_csv('bachelor_degree_analysis_sortedByDebtMean.csv')
# Out:
#                                            Unnamed: 0  P_CIPDESC
# 0   Business Administration, Management and Operat...       1431
# 1                                Psychology, General.       1098
# 2   Registered Nursing, Nursing Administration, Nu...        910
# 3                                   Biology, General.        904
# 4                   Criminal Justice and Corrections.        858
# 5                    Accounting and Related Services.        792
# 6   Teacher Education and Professional Development...        680
# 7                    Communication and Media Studies.        610
# 8           English Language and Literature, General.        577
# 9              Health and Physical Education/Fitness.        530
# 10                  Political Science and Government.        511
# 11                                           History.        465
# 12                                         Sociology.        464
# ...

# %%
sorted = sortedByDebtPayment10YR.groupby('P_CIPDESC')
debtPaymentsByMajor = sorted['P_DEBTPAYMENT10YR'].mean()
debtPaymentsByMajor
# Out:
# P_CIPDESC
# Accounting and Related Services.                          281.854798
# Aerospace, Aeronautical and Astronautical Engineering.    245.370370
# Agricultural Business and Management.                     196.068966
# Agricultural Engineering.                                 234.562500
# Agricultural Mechanization.                               211.000000
#                                                              ...
# Visual and Performing Arts, General.                      296.508475
# Visual and Performing Arts, Other.                        270.500000
# Wildlife and Wildlands Science and Management.            241.321429
# Woodworking.                                              280.000000
# Zoology/Animal Biology.                                   232.861111
# Name: P_DEBTPAYMENT10YR, Length: 292, dtype: float64

# %%
debtPaymentsByMajor.to_csv('bachelor_degree_analysis_sortedByDebtPayment10YRByMajor.csv')

# %%
# Rename columns to be the same as in our earnings data set
debtPaymentsByMajorRenamed = debtPaymentsByMajor.rename(index={
    'Accounting and Related Services.':'Accounting',
'Aerospace, Aeronautical and Astronautical Engineering.':'Aerospace Engineering',
'Agriculture, General.':'Agriculture',
'Anthropology.':'Anthropology',
'Architecture.':'Architecture',
'Arts, Entertainment,and Media Management.':'Art History',
'Biology, General.':'Biology',
'Business Administration, Management and Operations.':'Business Management',
'Chemical Engineering.':'Chemical Engineering',
'Chemistry.':'Chemistry',
'Civil Engineering.':'Civil Engineering',
'Communication, Journalism, and Related Programs, Other.':'Communications',
'Computer Engineering.':'Computer Engineering',
'Computer Science.':'Computer Science',
'Construction Engineering.':'Construction',
'Criminal Justice and Corrections.':'Criminal Justice',
'Drama/Theatre Arts and Stagecraft.':'Drama',
'Economics.':'Economics',
'Education, General.':'Education',
'Electrical Engineering Technologies/Technicians.':'Electrical Engineering',
'English Language and Literature, General.':'English',
'Film/Video and Photographic Arts.':'Film',
'Finance and Financial Management Services.':'Finance',
'Forestry.':'Forestry',
'Geography and Cartography.':'Geography',
'Geological/Geophysical Engineering.':'Geology',
'Graphic Communications.':'Graphic Design',
'Health and Medical Administrative Services.':'Health Care Administration',
'History.':'History',
'Hospitality Administration/Management.':'Hospitality & Tourism',
'Industrial Engineering.':'Industrial Engineering',
'Information Science/Studies.':'Information Technology (IT)',
'Interior Architecture.':'Interior Design',
'International Relations and National Security Studies.':'International Relations',
'Journalism.':'Journalism',
'Management Information Systems and Services.':'Management Information Systems (MIS)',
'Marketing.':'Marketing',
'Mathematics.':'Math',
'Mechanical Engineering.':'Mechanical Engineering',
'Music.':'Music',
'Nursing.':'Nursing',
'Nutrition Sciences.':'Nutrition',
'Philosophy.':'Philosophy',
'Physics.':'Physics',
'Political Science and Government.':'Political Science',
'Psychology, General.':'Psychology',
'Religion/Religious Studies.':'Religion',
'Sociology.':'Sociology'
})
debtPaymentsByMajorRenamed
# Out:
# P_CIPDESC
# Accounting                                        281.854798
# Aerospace Engineering                             245.370370
# Agricultural Business and Management.             196.068966
# Agricultural Engineering.                         234.562500
# Agricultural Mechanization.                       211.000000
#                                                      ...
# Visual and Performing Arts, General.              296.508475
# Visual and Performing Arts, Other.                270.500000
# Wildlife and Wildlands Science and Management.    241.321429
# Woodworking.                                      280.000000
# Zoology/Animal Biology.                           232.861111
# Name: P_DEBTPAYMENT10YR, Length: 292, dtype: float64

# %%
bachelorDegreesPayRenamed = bachelorDegreesPay.rename(columns={'Undergraduate Major':'P_CIPDESC'})
bachelorDegreesPayRenamed
# Out:
#                                P_CIPDESC Starting Median Salary  \
# 0                             Accounting             $46,000.00
# 1                  Aerospace Engineering             $57,700.00
# 2                            Agriculture             $42,600.00
# 3                           Anthropology             $36,800.00
# 4                           Architecture             $41,600.00
# 5                            Art History             $35,800.00
# 6                                Biology             $38,800.00
# 7                    Business Management             $43,000.00
# 8                   Chemical Engineering             $63,200.00
# 9                              Chemistry             $42,600.00
# 10                     Civil Engineering             $53,900.00
# 11                        Communications             $38,100.00
# 12                  Computer Engineering             $61,400.00
# 13                      Computer Science             $55,900.00
# ...

# %%
mergedDataFrame = pd.merge(debtPaymentsByMajorRenamed, bachelorDegreesPayRenamed, on='P_CIPDESC')
mergedDataFrame
# Out:
#                                P_CIPDESC  P_DEBTPAYMENT10YR  \
# 0                             Accounting         281.854798
# 1                  Aerospace Engineering         245.370370
# 2                            Agriculture         213.344828
# 3                           Anthropology         235.922652
# 4                           Architecture         283.046512
# 5                            Art History         263.437500
# 6                                Biology         243.463496
# 7                    Business Management         300.316562
# 8                   Chemical Engineering         237.080882
# 9                              Chemistry         231.125561
# 10                     Civil Engineering         242.071429
# 11                        Communications         244.608696
# 12                  Computer Engineering         270.128205
# 13                      Computer Science         235.688679
# 14                          Construction         284.166667
# ...

# %%
# Update monthly payments to get an annual values
mergedDataFrame['P_DEBTPAYMENT10YR'] = mergedDataFrame['P_DEBTPAYMENT10YR'].apply(lambda x: x*12)
mergedDataFrame
# Out:
#                                P_CIPDESC  P_DEBTPAYMENT10YR  \
# 0                             Accounting        3382.257576
# 1                  Aerospace Engineering        2944.444444
# 2                            Agriculture        2560.137931
# 3                           Anthropology        2831.071823
# 4                           Architecture        3396.558140
# 5                            Art History        3161.250000
# 6                                Biology        2921.561947
# 7                    Business Management        3603.798742
# 8                   Chemical Engineering        2844.970588
# 9                              Chemistry        2773.506726
# 10                     Civil Engineering        2904.857143
# 11                        Communications        2935.304348
# 12                  Computer Engineering        3241.538462
# 13                      Computer Science        2828.264151
# 14                          Construction        3410.000000
# ...

# %%
mergedDataFrame['Average Percent Of Salary'] =  mergedDataFrame['P_DEBTPAYMENT10YR']/mergedDataFrame['Starting Median Salary'].replace('[\$,]', '', regex=True).astype(float)*100
mergedDataFrame
# Out:
#                                P_CIPDESC  P_DEBTPAYMENT10YR  \
# 0                             Accounting        3382.257576
# 1                  Aerospace Engineering        2944.444444
# 2                            Agriculture        2560.137931
# 3                           Anthropology        2831.071823
# 4                           Architecture        3396.558140
# 5                            Art History        3161.250000
# 6                                Biology        2921.561947
# 7                    Business Management        3603.798742
# 8                   Chemical Engineering        2844.970588
# 9                              Chemistry        2773.506726
# 10                     Civil Engineering        2904.857143
# 11                        Communications        2935.304348
# 12                  Computer Engineering        3241.538462
# 13                      Computer Science        2828.264151
# 14                          Construction        3410.000000
# ...

# %%
# Select specific columns to output the data
outputData = mergedDataFrame[['P_CIPDESC','P_DEBTPAYMENT10YR',  'Starting Median Salary', 'Average Percent Of Salary']]
outputData = outputData.rename(columns={
    'P_CIPDESC':'Undergraduate Major',
    'P_DEBTPAYMENT10YR':'Annual Payment First 10YR'})

outputData['Starting Median Salary'] = outputData['Starting Median Salary'].replace('[\$,]', '', regex=True).astype(float)

# Undergraduate Major with the lowest payment of your salary will appear on top the list
# the top items are considered majors with highest rate of return on your education investments
outputData = outputData.sort_values(by='Average Percent Of Salary')
outputData.to_csv('bachelor_degree_resultOfInvestmentReturnBasedOnMajor.csv')

# %%
# Grouping majors by type
# https://www.thebalancecareers.com/choosing-a-college-major-by-field-3570279
outputData.loc[outputData['Undergraduate Major'] == 'Chemical Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Industrial Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Mechanical Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Computer Science', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Aerospace Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Computer Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Civil Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Physics', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Economics', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Management Information Systems (MIS)', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Math', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Agriculture', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Finance', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Construction', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Chemistry', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'International Relations', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Philosophy', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Nutrition', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Geography', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Political Science', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Forestry', 'Major Type'] = 'Environment-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Information Technology (IT)', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Accounting', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'History', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Geology', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Marketing', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Hospitality & Tourism', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Biology', 'Major Type'] = 'Environment-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'English', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Anthropology', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Communications', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Sociology', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Drama', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Architecture', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Journalism', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Interior Design', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Business Management', 'Major Type'] = 'Business-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Psychology', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Music', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Nursing', 'Major Type'] = 'Science and Math-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Education', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Art History', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Film', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Religion', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Electrical Engineering', 'Major Type'] = 'Engineering and Technology Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Graphic Design', 'Major Type'] = 'Arts-Related Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Criminal Justice', 'Major Type'] = 'Literature, Language, and Social Science Majors'

outputData.loc[outputData['Undergraduate Major'] == 'Health Care Administration', 'Major Type'] = 'Business-Related Majors'

outputData
# Out:
#                      Undergraduate Major  Annual Payment First 10YR  \
# 8                   Chemical Engineering                2844.970588
# 30                Industrial Engineering                2864.338983
# 38                Mechanical Engineering                2883.872340
# 13                      Computer Science                2828.264151
# 1                  Aerospace Engineering                2944.444444
# 12                  Computer Engineering                3241.538462
# 10                     Civil Engineering                2904.857143
# 43                               Physics                2715.103448
# 17                             Economics                2767.370920
# 35  Management Information Systems (MIS)                2858.294118
# 37                                  Math                2666.267717
# 2                            Agriculture                2560.137931
# 22                               Finance                2951.682540
# ...

# %%
# Assumptions
# Average S&P return for a year is 9.8%
# Calculation doesn't account for pay increases, inflation, employer matches.
# The person starting to contribute for retirement at the age of 25.  Average percentage of that salary should be 15% based on Fidelity data(https://www.fidelity.com/viewpoints/retirement/how-much-money-should-I-save) 

# 10 years of contributing 15% of the salary reduced by education payment
# when person graduated and can invest 15% of the salary to the retiment account but education debts reducing contributed amount

# Variables
percentOfSalary = 15
returnOfStandardAndPoorsInvestment = 9.8

outputData['Available Investments'] = (outputData['Starting Median Salary']/100) * (percentOfSalary - outputData['Average Percent Of Salary'])
outputData['Retirement Savings In 10 Years'] = 0 

for i in range(1, 11):
    runningGrowthForYear = outputData['Retirement Savings In 10 Years'] / 100 * returnOfStandardAndPoorsInvestment
    outputData['Retirement Savings In 10 Years'] = outputData['Retirement Savings In 10 Years'] + runningGrowthForYear + outputData['Available Investments']
    outputData[str(i)] = outputData['Retirement Savings In 10 Years']     

outputData.to_csv('bachelor_degree_resultOfInvestmentReturnBasedOnMajorByType.csv')

outputData
# Out:
#                      Undergraduate Major  Annual Payment First 10YR  \
# 8                   Chemical Engineering                2844.970588
# 30                Industrial Engineering                2864.338983
# 38                Mechanical Engineering                2883.872340
# 13                      Computer Science                2828.264151
# 1                  Aerospace Engineering                2944.444444
# 12                  Computer Engineering                3241.538462
# 10                     Civil Engineering                2904.857143
# 43                               Physics                2715.103448
# 17                             Economics                2767.370920
# 35  Management Information Systems (MIS)                2858.294118
# 37                                  Math                2666.267717
# 2                            Agriculture                2560.137931
# 22                               Finance                2951.682540
# ...
