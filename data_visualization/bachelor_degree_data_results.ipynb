# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
outputData = pd.read_csv('../data_analysis/bachelor_degree_resultOfInvestmentReturnBasedOnMajorByType.csv')

outputData
# Out:
#                   Computer Science
# 4            1                 Aerospace Engineering
# 5           12                  Computer Engineering
# 6           10                     Civil Engineering
# 7           43                               Physics
# 8           17                             Economics
# 9           35  Management Information Systems (MIS)
# 10          37                                  Math
# 11           2                           Agriculture
# 12          22                               Finance
# 13          14                          Construction
# 14           9                             Chemistry
# 15          33               International Relations
# 16          42                            Philosophy
# 17          41                             Nutrition
# 18          24                             Geography
# 19          44                     Political Science
# 20          23                              Forestry
# ...

# %%
sb.catplot(x="Average Percent Of Salary", y="Major Type", data=outputData)

# %%
sb.lmplot(x='Average Percent Of Salary', y='Starting Median Salary', data=outputData)

# %%
sb.lmplot(x='Average Percent Of Salary', y='Starting Median Salary', data=outputData,
           fit_reg=False, # No regression line
           hue='Major Type')   # Color by percentage

# %%
outputData
# Out:
#                   Computer Science
# 4            1                 Aerospace Engineering
# 5           12                  Computer Engineering
# 6           10                     Civil Engineering
# 7           43                               Physics
# 8           17                             Economics
# 9           35  Management Information Systems (MIS)
# 10          37                                  Math
# 11           2                           Agriculture
# 12          22                               Finance
# 13          14                          Construction
# 14           9                             Chemistry
# 15          33               International Relations
# 16          42                            Philosophy
# 17          41                             Nutrition
# 18          24                             Geography
# 19          44                     Political Science
# 20          23                              Forestry
# ...

# %%
# Find a median value by major type for Retirement Savings In 10 Years
df = outputData.pivot_table(index='Major Type', values='Retirement Savings In 10 Years', aggfunc=np.median).sort_values(by ='Retirement Savings In 10 Years', ascending=False)
sb.heatmap(df, annot=True, fmt=".1f")
# Out:
# <AxesSubplot:ylabel='Major Type'>

# %%
#Adding the trade data from bls.gov for a few example trade skills to compare college graduates with (added by patrick)
trade_data = pd.read_csv('../data_analysis/Sample-Trade-Salaries-2018.csv')
trade_data
# Out:
#                                      Occupation  Median Annual Wage 2018  \
# 0                                    Carpenters                    46590
# 1                         Construction Laborers                    35800
# 2  Electrical power-line installers and repairs                    70910
# 3                                  Electricians                    55190
# 4       Heavy and tractor-trailer truck drivers                    43680
# 5       Plumbers, pipefitters, and steamfitters                    53910
# 6                           sheet metal workers                    48460
#
#    Annual Contribution  10-Year total contribution  10-Year Retirement
# 0               6988.5                       69885            76733.73
# 1               5370.0                       53700            58962.60
# 2              10636.5                      106365           116788.77
# 3               8278.5                       82785            90897.93
# ...

# %%
df_trade = trade_data.pivot_table(index='Occupation', values='10-Year Retirement').sort_values(by='10-Year Retirement', ascending=False)
sb.heatmap(df_trade, annot=True, fmt=" .1f")
# Out:
# <AxesSubplot:ylabel='Occupation'>

# %%
#Pulling data to demonstrate late career earning potential of college graduates
college_data = pd.read_csv('../data_analysis/datasets_1189_2137_degrees-that-pay-back.cleaner.csv')
college_data
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                   46000
# 1                  Aerospace Engineering                   57700
# 2                            Agriculture                   42600
# 3                           Anthropology                   36800
# 4                           Architecture                   41600
# 5                            Art History                   35800
# 6                                Biology                   38800
# 7                    Business Management                   43000
# 8                   Chemical Engineering                   63200
# 9                              Chemistry                   42600
# 10                     Civil Engineering                   53900
# 11                        Communications                   38100
# 12                  Computer Engineering                   61400
# ...

# %%
df_mid_career = college_data.pivot_table(index='Undergraduate Major', values='Mid-Career 90th Percentile Salary').sort_values(by='Mid-Career 90th Percentile Salary', ascending=False)
df_mid_career.plot(kind='barh', figsize=(6,15))
#ax = sb.barplot(x='Mid-Career 75th Percentile Salary', y='Undergraduate Major',data=college_data)
#sb.heatmap(df_mid_career, annot=True, fmt=" .1f")
# Out:
# <AxesSubplot:ylabel='Undergraduate Major'>

# %%
avg_increase = college_data['Percent change from Starting to Mid-Career Salary'].mean()
avg_increase
# Out:
# 69.274

# %%
college_data['Mid-Career 25th Percentile Salary'] >70910
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Mid-Career 25th Percentile Salary, dtype: bool

# %%
college_data['Mid-Career 75th Percentile Salary'] >70910
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41    False
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48     True
# 49     True
# Name: Mid-Career 75th Percentile Salary, dtype: bool

# %%
college_data['Mid-Career 90th Percentile Salary'] >70910
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# Name: Mid-Career 90th Percentile Salary, dtype: bool
